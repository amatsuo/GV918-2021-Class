# %% [markdown]
# # Week 08: Exercise 1

# %% [markdown]
# ## Database
#
# In this exercise, we will explore the vaccination takeup rate at county level in the US. We see how it's related to some political variables which you used in Assignment 1.
#
# The database is in sqlite format.
#
# In the database, there are five tables.
#
# - `demography`
# - `pres_election`
# - `county`
# - `state`
# - `vaccination`: CDC data on Covid-19 vaccination in the US Counties
#   - The data is sliced to extract the first day of the month
#
# - The database is (semi-)normalized

# %%
# !wget https://www.dropbox.com/s/p77e0ea0c2psej5/vaccine.sqlite

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# ## Create a connection object

# %%
con_cov = sqlite3.connect('vaccine.sqlite')

# %% [markdown]
# ## Check tables

# %%
pd.read_sql_query("SELECT * FROM sqlite_master WHERE type='table'", con_cov)

# %% [markdown]
# ### Count the number of rows in tables

# %% [markdown]
# ## SQL query exercise
#
# 1. Get the vaccination data from March 2021
# 2. Get the vaccination data in NY from March 2021 (Hint: https://www.nrcs.usda.gov/wps/portal/nrcs/detail/?cid=nrcs143_013696)
# 3. Repeat 2. with table joining
# 4. Get the avarage of `Series_Complete_18PlusPop_Pct` by states in October 2021. Which is the highest?

# %% [markdown]
# ## Answer the following
#
# Now, let's compare the presidential vote, demography and vaccination takeup rate
#
# 1. Check Trump 2020 vote percentage, and correlate it with early (say March 2021) and late (October 2021) takeup rates
# 2. What about demograpy?

# %% [markdown]
# ### Visualize Trump vote and vaccination takeup

# %%
import matplotlib.pyplot as plt
import seaborn as sns
