# %% [markdown]
# In the part of the exercise, we will use a sqlite database created from [nycflights13](https://github.com/hadley/nycflights13).

# %%
# !wget https://www.dropbox.com/s/xv9di8fkqaokd5o/nycflight13.sqlite
# Out:
# --2021-11-21 20:22:45--  https://www.dropbox.com/s/xv9di8fkqaokd5o/nycflight13.sqlite
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.7.18, 2620:100:601a:18::a27d:712
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.7.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/xv9di8fkqaokd5o/nycflight13.sqlite [following]
# --2021-11-21 20:22:46--  https://www.dropbox.com/s/raw/xv9di8fkqaokd5o/nycflight13.sqlite
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc7ef54bc2f758f996b36a93d4f4.dl.dropboxusercontent.com/cd/0/inline/BaZiWGqeBcazsVE_gxfPucEPuKDcnHpYaWdIlWp3aBSYK_2MbDjjFBDzfASZuF3qO3LkxVRb_x63ZLujnl9t5PQaD5Q2O6LYXkzo3a54iD-YWjrP_ha-3KW1zsUvhz43o_lvTlHCrmF7pVUfiUgTMMKw/file# [following]
# --2021-11-21 20:22:46--  https://uc7ef54bc2f758f996b36a93d4f4.dl.dropboxusercontent.com/cd/0/inline/BaZiWGqeBcazsVE_gxfPucEPuKDcnHpYaWdIlWp3aBSYK_2MbDjjFBDzfASZuF3qO3LkxVRb_x63ZLujnl9t5PQaD5Q2O6LYXkzo3a54iD-YWjrP_ha-3KW1zsUvhz43o_lvTlHCrmF7pVUfiUgTMMKw/file
# Resolving uc7ef54bc2f758f996b36a93d4f4.dl.dropboxusercontent.com (uc7ef54bc2f758f996b36a93d4f4.dl.dropboxusercontent.com)... 162.125.7.15, 2620:100:601a:15::a27d:70f
# Connecting to uc7ef54bc2f758f996b36a93d4f4.dl.dropboxusercontent.com (uc7ef54bc2f758f996b36a93d4f4.dl.dropboxusercontent.com)|162.125.7.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Bab738ehtZ4e7_Fn5-RLSzdpKlrAY2_Cye_llLCLCRT2j-TfP6ukdb_6TWdZmpWe9AvIV4Ezvk1CfFVBXk5gwAYZGGs621NcefRIHQcb0ko1ZXWfFySBum6ClepbbJzEoMqLr9x5nyBFlahLf4c30C4vMTGfUjJzTQTtq6hkRvE7QgRD_IbCg5NAtf9ItPwP7Yt3WQho3rVceC6PlGRrU4kuVdNh64oinxn4hmFmBgY0s82j0qOSuab0O9vgkOQ5MvxZ4TUcyZbIY_RXIl4jNITzEhkZWj1xAvfBwClvimfckH7KoAQauYW8VgUj91N-UDSoRFNw1MUyQqjonbkHaDX5pu5mroRNhcOIs5QBzbmDIY85t6HYzyTIW-YIUeTw8gc/file [following]
# --2021-11-21 20:22:46--  https://uc7ef54bc2f758f996b36a93d4f4.dl.dropboxusercontent.com/cd/0/inline2/Bab738ehtZ4e7_Fn5-RLSzdpKlrAY2_Cye_llLCLCRT2j-TfP6ukdb_6TWdZmpWe9AvIV4Ezvk1CfFVBXk5gwAYZGGs621NcefRIHQcb0ko1ZXWfFySBum6ClepbbJzEoMqLr9x5nyBFlahLf4c30C4vMTGfUjJzTQTtq6hkRvE7QgRD_IbCg5NAtf9ItPwP7Yt3WQho3rVceC6PlGRrU4kuVdNh64oinxn4hmFmBgY0s82j0qOSuab0O9vgkOQ5MvxZ4TUcyZbIY_RXIl4jNITzEhkZWj1xAvfBwClvimfckH7KoAQauYW8VgUj91N-UDSoRFNw1MUyQqjonbkHaDX5pu5mroRNhcOIs5QBzbmDIY85t6HYzyTIW-YIUeTw8gc/file
# Reusing existing connection to uc7ef54bc2f758f996b36a93d4f4.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24510464 (23M) [application/octet-stream]
# Saving to: ‘nycflight13.sqlite’
#
# nycflight13.sqlite  100%[===================>]  23.38M  79.5MB/s    in 0.3s
#
# 2021-11-21 20:22:47 (79.5 MB/s) - ‘nycflight13.sqlite’ saved [24510464/24510464]

# %%
import pandas as pd
import sqlite3
con_flight = sqlite3.connect('nycflight13.sqlite')

# %% [markdown]
# ## Questions
#
# 1. Number of flights with more than two hours of departure delay
# 2. Number of flights with more than two hours of departure delay by month and origin airport
# 3. Number of flights with more than two hours of delay by airline (use airlines' full names (Example: American Airlines Inc.))
# 4. Proportion of flights with more than two hours of delay by airline (you can run query twice and create two dfs and merge in Python)

# %% [markdown]
# ## Flight delays and airplane
#
# Using two tables, explore the relations between departure delays and ages of airplanes. Are there any relations?
